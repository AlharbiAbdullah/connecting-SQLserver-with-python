# %%
import pandas as pd     #to convert data coming from DB to DataFrame 
import numpy as np      #using it to get column
import pyodbc as pydb   #to build a connection between sql server & python

# %%
# building the connection 
conn = pydb.connect('Driver={SQL Server Native Client 11.0};'
                      'Server=DESKTOP-HQ1LCKU;'
                      'Database=Testing;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
sql = cursor.execute('SELECT STATMENT HERE').fetchall()

# creating list of tuples and store it as datafame 
df = pd.DataFrame([tuple(t) for t in sql]) 
# fetching the column names
df.columns = pd.DataFrame(np.matrix(cursor.description))[0]

# %%
df.head()
# Out:
# 0 CUST_CODE CUST_NAME                            CUST_CITY WORKING_AREA  \
# 0    C00001   Micheal  New York                                New York
# 1    C00002      Bolt  New York                                New York
# 2    C00003    Martin  Torento                                  Torento
# 3    C00004   Winston  Brisban                                  Brisban
# 4    C00005  Sasikant  Mumbai                                    Mumbai
#
# 0 CUST_COUNTRY GRADE OPENING_AMT RECEIVE_AMT PAYMENT_AMT OUTSTANDING_AMT  \
# 0          USA     2     3000.00     5000.00     2000.00         6000.00
# 1          USA     3     5000.00     7000.00     9000.00         3000.00
# 2       Canada     2     8000.00     7000.00     7000.00         8000.00
# 3    Australia     1     5000.00     8000.00     7000.00         6000.00
# 4        India     1     7000.00    11000.00     7000.00        11000.00
#
# 0      PHONE_NO AGENT_CODE
# 0       CCCCCCC     A008
# 1       DDNRDRH     A008
# ...

# %%
df.
